# %% [markdown]
# Express each of the following expressions in the form $2^m3^na^rb^s$, where m, n, r, s are positive integers.
#
# 1. $8a^2b^3(27a^4)(2^5ab)$
# 2. $16b^3a^2(6ab^4)(ab)^3$
# 3. $3^2(2ab)^3(16a^2b^5)(24b^2a)$
