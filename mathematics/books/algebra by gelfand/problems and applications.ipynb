# %% [markdown]
# This notebook covers problems and applications from Gelfand's book on algebra.

# %% [markdown]
# ### Introductiorary puzzles
#
# for example "a boy claims that he can multiply any three-digit number by 1001 instantly. If his classmate says to him "715" he gives the answer immediately. Compute the answer and explain the boy's secret
#
# Multiply 101010101 by 57 that gives 5757575757
# Multiply 10001 by 1020304050 that would give 1020304050102030405
#
# The boy's secret is that when the number you multiply by 1001 you have that $n x 1000 = n x 1000 + n x 1 = 1000n+n$ so if $n = 2$ you have $2 x 1000 + 2 x 1 = 2002$. Since $n$ is a three-digit number, 1000 $n$ shifts exaclt three places to the left - leaving three empty digit slots that $n$ fills perfectly so the result is just $n$ written twice back-to-back.
#
#
# A six-digit number having 1 as its leftmost digit becomes three times bigger if we take this digit off and put it at the end of the number. What is the number?
#
# So were looking for a number $n$ is 6 digits and the left most digit of $n$ is 1.
#
# Since this book is about algebra we might consider how to write this in algebraic form.
#
# We can again form this algrebraically where we let $m$ be the five-digit number formed by the last five digits of $n$ then we have $n = 100000 + m$.

# %% [markdown]
# ## Aritmetic operations
#
# Here are two examples of some simple arithmetic where the associative law can be used to make the counting more simple.
#
# 357 + 17999 + 1 = (17999 + 1) + 357 = 18000 + 357 = 18357
#
# 899 + 1343 + 101 = (899 + 101) + 1343 = 1000 + 1343 = 2343
#
# ![image.png](attachment:image.png)
