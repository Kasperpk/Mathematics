# %% [markdown]
# # Problem: [Title]
#
# **Date**: YYYY-MM-DD
# **Domain**: <!-- Mathematics / Physics / CS / Biology / Professional / Personal -->
# **Type**: <!-- Spatial / Logic / Algebraic / Algorithmic / Probabilistic / Design / Decision / Number Theory / Combinatorics -->
# **Difficulty**: ★☆☆☆☆
# **Source**: <!-- Zeitz ch.X / Gelfand / Work / Personal / Book title -->

# %% [markdown]
# ## Problem Statement
#
# > State the problem clearly and precisely. Write it in your own words.

# %% [markdown]
# ## First Look — What do I notice?
#
# - What is this problem *really* asking?
# - Visualize it. Draw it. Make an Excalidraw sketch if helpful.
# - What does this remind you of? Is there an analogous simpler problem?
# - What's the smallest concrete version I can fully understand?

# %% [markdown]
# ## Strategy
#
# What approach am I taking and why?
#
# <!-- Common strategies: wishful thinking · invariants · symmetry · proof by contradiction ·
#      draw a picture · work backwards · small cases · pigeonhole · induction · cases -->

# %% [markdown]
# ## Solution
#
# _Step-by-step reasoning. Show your work._

# %%
# Optional: use Python to verify, simulate, or visualize

# %% [markdown]
# ## Key Insight
#
# > One sentence: the core trick that made this work.

# %% [markdown]
# ## Generalization
#
# - What family of problems does this belong to?
# - Where else does this technique apply?
# - What problem does this open up next?

# %% [markdown]
# ## Reflection
#
# - What would I have done differently?
# - What surprised me?
# - What does this teach me about problem-solving in general?
